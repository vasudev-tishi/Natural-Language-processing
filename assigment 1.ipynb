# %%
import PyPDF2
import re

# %%
nlp = "Natural Language Processing using the variables provided."

# %%
print(f"NLP Stand for :- {nlp}")
# Out:
# NLP Stand for :- Natural Language Processing using the variables provided.

# %%
f = open("contacts.txt", "w")
f.write(nlp)
# Out:
# 57

# %%
f = open("contacts.txt", "r")
fields = f.read()
print(fields)
f.close()
# Out:
# Natural Language Processing using the variables provided.

# %%
with open(r"C:\Users\DELL\Desktop\Business_Proposal.pdf", "rb") as pdf_file:
    read = PyPDF2.PdfReader(pdf_file)
    page = read.pages[1].extract_text() 

print(page)
# Out:
# AUTHORS:
# Amy Baker, Finance Chair, x345, abaker@ourcompany.com
# Chris Donaldson, Accounting Dir., x621, cdonaldson@ourcompany.com
# Erin Freeman, Sr. VP, x879, efreeman@ourcompany.com

# %%
f= open("contacts.txt", "a")
f.write(f"\n{page}")
# Out:
# 189

# %%
print(page)
# Out:
# AUTHORS:
# Amy Baker, Finance Chair, x345, abaker@ourcompany.com
# Chris Donaldson, Accounting Dir., x621, cdonaldson@ourcompany.com
# Erin Freeman, Sr. VP, x879, efreeman@ourcompany.com

# %%
f.close()

# %%
emails = re.findall(r"[\w]+@[\w]+.[\w]+", page)
print(emails)
# Out:
# ['abaker@ourcompany.com', 'cdonaldson@ourcompany.com', 'efreeman@ourcompany.com']
